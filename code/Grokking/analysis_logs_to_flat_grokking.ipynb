# %% [markdown]
# ## Загрузка библиотек

# %%
from grokking_analysis import (
    get_tau_dmi, get_tau_fixed,
    get_E_fnn, get_E_simplex,
    get_E_cao, get_E_mle,
    analyze_grokking_dimensionality
)

# %% [markdown]
# ## EDM анализ данных для train loss при $\tau = 1$

# %%
csv_file = 'grokking_logs/grokking_modular_addition_logs_to_flat_grokking.csv'
    
W_SIZE = 300
S_SIZE = 50

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_fnn, 
    method_name="Classic FNN",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_to_flat_grokking' 
)

stepss, E_his, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_cao, 
    method_name="Cao Method E1",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_to_flat_grokking' 
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_simplex, 
    method_name="Simplex Projection",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_to_flat_grokking' 
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed,
    E_func=get_E_mle, 
    method_name="MLE Intrinsic Dimension",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_to_flat_grokking' 
)
# Out:
# --- Running Grokking Analysis: Classic FNN ---
# Sliding Window: 100%|██████████████████████████████████████████████████████████████| 394/394 [00:00<00:00, 1166.63it/s]
# --- Running Grokking Analysis: Cao Method E1 ---
# Sliding Window: 100%|██████████████████████████████████████████████████████████████| 394/394 [00:00<00:00, 1587.07it/s]
# --- Running Grokking Analysis: Simplex Projection ---
# Sliding Window: 100%|███████████████████████████████████████████████████████████████| 394/394 [00:02<00:00, 169.67it/s]
# --- Running Grokking Analysis: MLE Intrinsic Dimension ---
# Sliding Window: 100%|██████████████████████████████████████████████████████████████| 394/394 [00:00<00:00, 4401.89it/s]

# %% [markdown]
# ## EDM анализ данных для val loss при $\tau = 1$

# %%
csv_file = 'grokking_logs/grokking_modular_addition_logs_to_flat_grokking.csv'
    
W_SIZE = 300
S_SIZE = 50

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_fnn, 
    method_name="Classic FNN",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_to_flat_grokking_for_val_loss'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_cao, 
    method_name="Cao Method E1",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_to_flat_grokking_for_val_loss'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_simplex, 
    method_name="Simplex Projection",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_to_flat_grokking_for_val_loss'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed,
    E_func=get_E_mle, 
    method_name="MLE Intrinsic Dimension",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_to_flat_grokking_for_val_loss'
)
# Out:
# --- Running Grokking Analysis: Classic FNN ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 394/394 [00:05<00:00, 68.84it/s]
# --- Running Grokking Analysis: Cao Method E1 ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 394/394 [00:07<00:00, 53.55it/s]
# --- Running Grokking Analysis: Simplex Projection ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 394/394 [00:24<00:00, 16.17it/s]
# --- Running Grokking Analysis: MLE Intrinsic Dimension ---
# Sliding Window: 100%|███████████████████████████████████████████████████████████████| 394/394 [00:00<00:00, 758.15it/s]

# %% [markdown]
# ## EDM анализ данных для weight norm при $\tau = 1$

# %%
csv_file = 'grokking_logs/grokking_modular_addition_logs_to_flat_grokking.csv'
    
W_SIZE = 300
S_SIZE = 50

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_fnn, 
    method_name="Classic FNN",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_to_flat_grokking_for_weight_norm'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_cao, 
    method_name="Cao Method E1",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_to_flat_grokking_for_weight_norm'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_simplex, 
    method_name="Simplex Projection",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_to_flat_grokking_for_weight_norm'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed,
    E_func=get_E_mle, 
    method_name="MLE Intrinsic Dimension",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_to_flat_grokking_for_weight_norm'
)
# Out:
# --- Running Grokking Analysis: Classic FNN ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 394/394 [00:10<00:00, 38.65it/s]
# --- Running Grokking Analysis: Cao Method E1 ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 394/394 [00:10<00:00, 38.88it/s]
# --- Running Grokking Analysis: Simplex Projection ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 394/394 [00:49<00:00,  7.92it/s]
# --- Running Grokking Analysis: MLE Intrinsic Dimension ---
# Sliding Window: 100%|███████████████████████████████████████████████████████████████| 394/394 [00:01<00:00, 369.81it/s]
