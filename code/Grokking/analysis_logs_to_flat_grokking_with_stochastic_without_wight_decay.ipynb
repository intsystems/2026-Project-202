# %% [markdown]
# ## Загрузка библиотек

# %%
from grokking_analysis import (
    get_tau_dmi, get_tau_fixed,
    get_E_fnn, get_E_simplex,
    get_E_cao, get_E_mle,
    analyze_grokking_dimensionality
)

# %% [markdown]
# ## EDM анализ данных для train loss при $\tau = 1$

# %%
csv_file = 'grokking_logs/grokking_modular_addition_logs_to_flat_grokking_with_stochastic_without_wight_decay.csv'
    
W_SIZE = 300
S_SIZE = 50

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_fnn, 
    method_name="Classic FNN",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_to_flat_grokking_with_stochastic_without_wight_decay' 
)

stepss, E_his, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_cao, 
    method_name="Cao Method E1",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_to_flat_grokking_with_stochastic_without_wight_decay' 
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_simplex, 
    method_name="Simplex Projection",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_to_flat_grokking_with_stochastic_without_wight_decay' 
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed,
    E_func=get_E_mle, 
    method_name="MLE Intrinsic Dimension",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_to_flat_grokking_with_stochastic_without_wight_decay' 
)
# Out:
# --- Running Grokking Analysis: Classic FNN ---
# Sliding Window: 100%|█████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 648.05it/s]
# --- Running Grokking Analysis: Cao Method E1 ---
# Sliding Window: 100%|█████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 499.38it/s]
# --- Running Grokking Analysis: Simplex Projection ---
# Sliding Window: 100%|█████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 203.47it/s]
# --- Running Grokking Analysis: MLE Intrinsic Dimension ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 4776.95it/s]

# %% [markdown]
# ## EDM анализ данных для val loss при $\tau = 1$

# %%
csv_file = 'grokking_logs/grokking_modular_addition_logs_to_flat_grokking_with_stochastic_without_wight_decay.csv'

W_SIZE = 300
S_SIZE = 50

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_fnn, 
    method_name="Classic FNN",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_to_flat_grokking_for_val_loss_with_stochastic_without_wight_decay'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_cao, 
    method_name="Cao Method E1",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_to_flat_grokking_for_val_loss_with_stochastic_without_wight_decay'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_simplex, 
    method_name="Simplex Projection",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_to_flat_grokking_for_val_loss_with_stochastic_without_wight_decay'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed,
    E_func=get_E_mle, 
    method_name="MLE Intrinsic Dimension",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_to_flat_grokking_for_val_loss_with_stochastic_without_wight_decay'
)
# Out:
# --- Running Grokking Analysis: Classic FNN ---
# Sliding Window: 100%|██████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 43.92it/s]
# --- Running Grokking Analysis: Cao Method E1 ---
# Sliding Window: 100%|██████████████████████████████████████████████████████████████████| 34/34 [00:01<00:00, 32.52it/s]
# --- Running Grokking Analysis: Simplex Projection ---
# Sliding Window: 100%|██████████████████████████████████████████████████████████████████| 34/34 [00:04<00:00,  7.23it/s]
# --- Running Grokking Analysis: MLE Intrinsic Dimension ---
# Sliding Window: 100%|█████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 405.33it/s]

# %% [markdown]
# ## EDM анализ данных для weight norm при $\tau = 1$

# %%
csv_file = 'grokking_logs/grokking_modular_addition_logs_to_flat_grokking_with_stochastic_without_wight_decay.csv'

W_SIZE = 300
S_SIZE = 50

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_fnn, 
    method_name="Classic FNN",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_to_flat_grokking_for_weight_norm_with_stochastic_without_wight_decay'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_cao, 
    method_name="Cao Method E1",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_to_flat_grokking_for_weight_norm_with_stochastic_without_wight_decay'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_simplex, 
    method_name="Simplex Projection",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_to_flat_grokking_for_weight_norm_with_stochastic_without_wight_decay'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed,
    E_func=get_E_mle, 
    method_name="MLE Intrinsic Dimension",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_to_flat_grokking_for_weight_norm_with_stochastic_without_wight_decay'
)
# Out:
# --- Running Grokking Analysis: Classic FNN ---
# Sliding Window: 100%|██████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 43.67it/s]
# --- Running Grokking Analysis: Cao Method E1 ---
# Sliding Window: 100%|██████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 43.70it/s]
# --- Running Grokking Analysis: Simplex Projection ---
# Sliding Window: 100%|██████████████████████████████████████████████████████████████████| 34/34 [00:04<00:00,  7.92it/s]
# --- Running Grokking Analysis: MLE Intrinsic Dimension ---
# Sliding Window: 100%|█████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 404.24it/s]
