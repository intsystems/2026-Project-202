# %% [markdown]
# ## Загрузка библиотек

# %%
from grokking_analysis import (
    get_tau_dmi, get_tau_fixed,
    get_E_fnn, get_E_simplex,
    get_E_cao, get_E_mle,
    analyze_grokking_dimensionality
)

# %% [markdown]
# ## EDM анализ данных для train loss при $\tau = 1$

# %%
csv_file = 'grokking_logs/grokking_modular_addition_logs_gd.csv'
    
W_SIZE = 300
S_SIZE = 50

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_fnn, 
    method_name="Classic FNN",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_gd' 
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_cao, 
    method_name="Cao Method E1",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_gd' 
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_simplex, 
    method_name="Simplex Projection",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_gd' 
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed,
    E_func=get_E_mle, 
    method_name="MLE Intrinsic Dimension",
    window_size=W_SIZE, step_size=S_SIZE,
    add_name='with_tau_1_gd' 
)
# Out:
# --- Running Grokking Analysis: Classic FNN ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 294/294 [00:06<00:00, 42.74it/s]
# --- Running Grokking Analysis: Cao Method E1 ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 294/294 [00:07<00:00, 38.47it/s]
# --- Running Grokking Analysis: Simplex Projection ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 294/294 [02:14<00:00,  2.19it/s]
# --- Running Grokking Analysis: MLE Intrinsic Dimension ---
# Sliding Window: 100%|███████████████████████████████████████████████████████████████| 294/294 [00:00<00:00, 334.79it/s]

# %% [markdown]
# ## EDM анализ данных для val loss при $\tau = 1$

# %%
csv_file = 'grokking_logs/grokking_modular_addition_logs_gd.csv'
    
W_SIZE = 300
S_SIZE = 50

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_fnn, 
    method_name="Classic FNN",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_gd_for_val_loss'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_cao, 
    method_name="Cao Method E1",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_gd_for_val_loss'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_simplex, 
    method_name="Simplex Projection",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_gd_for_val_loss'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed,
    E_func=get_E_mle, 
    method_name="MLE Intrinsic Dimension",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='val_loss',
    add_name='with_tau_1_gd_for_val_loss'
)
# Out:
# --- Running Grokking Analysis: Classic FNN ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 294/294 [00:07<00:00, 40.51it/s]
# --- Running Grokking Analysis: Cao Method E1 ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 294/294 [00:08<00:00, 34.15it/s]
# --- Running Grokking Analysis: Simplex Projection ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 294/294 [02:10<00:00,  2.26it/s]
# --- Running Grokking Analysis: MLE Intrinsic Dimension ---
# Sliding Window: 100%|███████████████████████████████████████████████████████████████| 294/294 [00:01<00:00, 286.91it/s]

# %% [markdown]
# ## EDM анализ данных для weight norm при $\tau = 1$

# %%
csv_file = 'grokking_logs/grokking_modular_addition_logs_gd.csv'
    
W_SIZE = 300
S_SIZE = 50

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_fnn, 
    method_name="Classic FNN",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_gd_for_weight_norm'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_cao, 
    method_name="Cao Method E1",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_gd_for_weight_norm'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed, 
    E_func=get_E_simplex, 
    method_name="Simplex Projection",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_gd_for_weight_norm'
)

_, _, _ = analyze_grokking_dimensionality(
    csv_file, 
    tau_func=get_tau_fixed,
    E_func=get_E_mle, 
    method_name="MLE Intrinsic Dimension",
    window_size=W_SIZE, step_size=S_SIZE,
    target_metric='weight_norm',
    add_name='with_tau_1_gd_for_weight_norm'
)
# Out:
# --- Running Grokking Analysis: Classic FNN ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 294/294 [00:07<00:00, 39.27it/s]
# --- Running Grokking Analysis: Cao Method E1 ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 294/294 [00:07<00:00, 38.18it/s]
# --- Running Grokking Analysis: Simplex Projection ---
# Sliding Window: 100%|████████████████████████████████████████████████████████████████| 294/294 [02:37<00:00,  1.86it/s]
# --- Running Grokking Analysis: MLE Intrinsic Dimension ---
# Sliding Window: 100%|███████████████████████████████████████████████████████████████| 294/294 [00:01<00:00, 236.38it/s]
